# %% [markdown]
# # Apple Stock

# %% [markdown]
# ### Introduction:
#
# We are going to use Apple's stock price.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv)

# %%
apple = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv')
apple.head(10)
# Out:
#          Date   Open   High    Low  Close    Volume  Adj Close
# 0  2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1  2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2  2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 3  2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 4  2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52
# 5  2014-06-30  92.10  93.73  92.09  92.93  49482300      92.93
# 6  2014-06-27  90.82  92.00  90.77  91.98  64006800      91.98
# 7  2014-06-26  90.37  91.05  89.80  90.90  32595800      90.90
# 8  2014-06-25  90.21  90.70  89.65  90.36  36852200      90.36
# 9  2014-06-24  90.75  91.74  90.19  90.28  38988300      90.28

# %% [markdown]
# ### Step 3. Assign it to a variable apple

# %% [markdown]
# ### Step 4.  Check out the type of the columns

# %%
apple.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %% [markdown]
# ### Step 5. Transform the Date column as a datetime type

# %%
apple['Date'] = pd.to_datetime(apple['Date'])

# %% [markdown]
# ### Step 6.  Set the date as the index

# %%
apple.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Volume                int64
# Adj Close           float64
# dtype: object

# %%
apple = apple.set_index('Date')

# %% [markdown]
# ### Step 7.  Is there any duplicate dates?

# %%
apple.shape[0]
# Out:
# 8465

# %%
apple.index.unique().shape[0]
# Out:
# 8465

# %% [markdown]
# ### Step 8.  Ops...it seems the index is from the most recent date. Make the first entry the oldest date.

# %%
ind = apple.index.sort_values(ascending=False)
apple.reindex(ind)
# Out:
#               Open    High     Low   Close     Volume  Adj Close
# Date
# 2014-07-08   96.27   96.80   93.92   95.35   65130000      95.35
# 2014-07-07   94.14   95.99   94.10   95.97   56305400      95.97
# 2014-07-03   93.67   94.10   93.20   94.03   22891800      94.03
# 2014-07-02   93.87   94.06   93.09   93.48   28420900      93.48
# 2014-07-01   93.52   94.07   93.13   93.52   38170200      93.52
# 2014-06-30   92.10   93.73   92.09   92.93   49482300      92.93
# 2014-06-27   90.82   92.00   90.77   91.98   64006800      91.98
# 2014-06-26   90.37   91.05   89.80   90.90   32595800      90.90
# 2014-06-25   90.21   90.70   89.65   90.36   36852200      90.36
# 2014-06-24   90.75   91.74   90.19   90.28   38988300      90.28
# 2014-06-23   91.32   91.62   90.60   90.83   43618200      90.83
# 2014-06-20   91.85   92.55   90.90   90.91  100813200      90.91
# 2014-06-19   92.29   92.30   91.34   91.86   35486400      91.86
# ...

# %% [markdown]
# ### Step 9. Get the last business day of each month

# %%
apple.index + pd.offsets.BMonthEnd()
# Out:
# DatetimeIndex(['2014-07-31', '2014-07-31', '2014-07-31', '2014-07-31',
#                '2014-07-31', '2014-07-31', '2014-06-30', '2014-06-30',
#                '2014-06-30', '2014-06-30',
#                ...
#                '1980-12-31', '1980-12-31', '1980-12-31', '1980-12-31',
#                '1980-12-31', '1980-12-31', '1980-12-31', '1980-12-31',
#                '1980-12-31', '1980-12-31'],
#               dtype='datetime64[ns]', name='Date', length=8465, freq=None)

# %%
apple_month = apple.resample('BM').mean()
apple_month
# Out:
#                   Open        High         Low       Close        Volume  \
# Date
# 1980-12-31   30.481538   30.567692   30.443077   30.443077  2.586252e+07
# 1981-01-30   31.754762   31.826667   31.654762   31.654762  7.249867e+06
# 1981-02-27   26.480000   26.572105   26.407895   26.407895  4.231832e+06
# 1981-03-31   24.937727   25.016818   24.836364   24.836364  7.962691e+06
# 1981-04-30   27.286667   27.368095   27.227143   27.227143  6.392000e+06
# 1981-05-29   29.052000   29.188000   28.995000   28.995000  7.380240e+06
# 1981-06-30   30.801818   30.876364   30.703636   30.703636  1.080189e+07
# 1981-07-31   24.436364   24.531818   24.374545   24.374545  7.584436e+06
# 1981-08-31   22.336500   22.386500   22.218500   22.218500  6.857760e+06
# 1981-09-30   18.221429   18.273810   18.131429   18.131429  8.853333e+06
# 1981-10-30   18.603182   18.722273   18.569091   18.569091  1.027473e+07
# 1981-11-30   18.697500   18.774000   18.642500   18.642500  7.333480e+06
# ...

# %% [markdown]
# ### Step 10.  What is the difference in days between the first day and the oldest

# %%
(apple.index.max() - apple.index.min()).days
# Out:
# 12261

# %% [markdown]
# ### Step 11.  How many months in the data we have?

# %%
apple_month.index.unique().shape[0]
# Out:
# 404

# %%
apple_month.reset_index().head()
# Out:
#         Date       Open       High        Low      Close        Volume  \
# 0 1980-12-31  30.481538  30.567692  30.443077  30.443077  2.586252e+07
# 1 1981-01-30  31.754762  31.826667  31.654762  31.654762  7.249867e+06
# 2 1981-02-27  26.480000  26.572105  26.407895  26.407895  4.231832e+06
# 3 1981-03-31  24.937727  25.016818  24.836364  24.836364  7.962691e+06
# 4 1981-04-30  27.286667  27.368095  27.227143  27.227143  6.392000e+06
#
#    Adj Close
# 0   0.473077
# 1   0.493810
# 2   0.411053
# 3   0.387727
# 4   0.423333

# %% [markdown]
# ### Step 12. Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
# sns.scatterplot(x='Date', y='Adj Close', data=apple_month.reset_index())
apple['Adj Close'].plot(figsize=(13.5, 9))

# %% [markdown]
# ### BONUS: Create your own question and answer it.
